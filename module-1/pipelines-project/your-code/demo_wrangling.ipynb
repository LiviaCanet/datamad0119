# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Adquire

demo = pd.read_csv('country_population.csv')

# %%
demo.head(11)
# Out:
#             Country Name Country Code     Indicator Name Indicator Code  \
# 0                  Aruba          ABW  Population, total    SP.POP.TOTL
# 1            Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2                 Angola          AGO  Population, total    SP.POP.TOTL
# 3                Albania          ALB  Population, total    SP.POP.TOTL
# 4                Andorra          AND  Population, total    SP.POP.TOTL
# 5             Arab World          ARB  Population, total    SP.POP.TOTL
# 6   United Arab Emirates          ARE  Population, total    SP.POP.TOTL
# 7              Argentina          ARG  Population, total    SP.POP.TOTL
# 8                Armenia          ARM  Population, total    SP.POP.TOTL
# 9         American Samoa          ASM  Population, total    SP.POP.TOTL
# 10   Antigua and Barbuda          ATG  Population, total    SP.POP.TOTL
#
#           1960        1961        1962         1963         1964         1965  \
# ...

# %%
#Missing Values

null_cols = demo.isnull().sum()
null_cols[null_cols > 0]
# Out:
# 1960    4
# 1961    4
# 1962    4
# 1963    4
# 1964    4
# 1965    4
# 1966    4
# 1967    4
# 1968    4
# 1969    4
# 1970    4
# 1971    4
# 1972    4
# 1973    4
# 1974    4
# 1975    4
# 1976    4
# 1977    4
# 1978    4
# 1979    4
# 1980    4
# 1981    4
# 1982    4
# 1983    4
# 1984    4
# 1985    4
# 1986    4
# 1987    4
# 1988    4
# 1989    4
# 1990    2
# 1991    2
# 1992    3
# 1993    3
# 1994    3
# 1995    2
# 1996    2
# 1997    2
# 1998    1
# 1999    1
# 2000    1
# 2001    1
# 2002    1
# 2003    1
# 2004    1
# 2005    1
# 2006    1
# 2007    1
# 2008    1
# 2009    1
# 2010    1
# 2011    1
# 2012    2
# 2013    2
# 2014    2
# 2015    2
# 2016    2
# dtype: int64

# %%
# Eliminamos las columnas que no vamos a utilizar

dropyears = [str(x) for x in range(1960, 1970)]
    
print(dropyears)
# Out:
# ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969']

# %%
# Eliminamos las columnas que no vamos a utilizar

demo = demo.drop(dropyears, axis=1)
demo.head(11)
# Out:
#             Country Name Country Code     Indicator Name Indicator Code  \
# 0                  Aruba          ABW  Population, total    SP.POP.TOTL
# 1            Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2                 Angola          AGO  Population, total    SP.POP.TOTL
# 3                Albania          ALB  Population, total    SP.POP.TOTL
# 4                Andorra          AND  Population, total    SP.POP.TOTL
# 5             Arab World          ARB  Population, total    SP.POP.TOTL
# 6   United Arab Emirates          ARE  Population, total    SP.POP.TOTL
# 7              Argentina          ARG  Population, total    SP.POP.TOTL
# 8                Armenia          ARM  Population, total    SP.POP.TOTL
# 9         American Samoa          ASM  Population, total    SP.POP.TOTL
# 10   Antigua and Barbuda          ATG  Population, total    SP.POP.TOTL
#
#            1970         1971         1972         1973         1974  \
# ...

# %%
# Eliminamos las columnas que no vamos a utilizar

demo = demo.drop(['Indicator Name', 'Indicator Code', 'Country Code'], axis=1)
demo.head(11)
# Out:
#             Country Name         1970         1971         1972         1973  \
# 0                  Aruba      59063.0      59440.0      59840.0      60243.0
# 1            Afghanistan   11126123.0   11417825.0   11721940.0   12027822.0
# 2                 Angola    6776381.0    6927269.0    7094834.0    7277960.0
# 3                Albania    2135479.0    2187853.0    2243126.0    2296752.0
# 4                Andorra      24276.0      25559.0      26892.0      28232.0
# 5             Arab World  122398374.0  125807419.0  129269375.0  132863416.0
# 6   United Arab Emirates     235499.0     278808.0     332760.0     397174.0
# 7              Argentina   23973058.0   24366439.0   24782949.0   25213388.0
# 8                Armenia    2525065.0    2587706.0    2650484.0    2712781.0
# 9         American Samoa      27292.0      27916.0      28492.0      29014.0
# 10   Antigua and Barbuda      67098.0      68188.0      69176.0      70066.0
#
# ...

# %%
# Eliminamos las filas que tienen el valor nulo

droprows = [str(x) for x in range(1970, 2017)]
print(droprows)
# Out:
# ['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']

# %%
# Eliminamos las filas que tienen el valor nulo
demo = demo.dropna(subset = droprows, axis=0)
demo.head(11)
# Out:
#             Country Name         1970         1971         1972         1973  \
# 0                  Aruba      59063.0      59440.0      59840.0      60243.0
# 1            Afghanistan   11126123.0   11417825.0   11721940.0   12027822.0
# 2                 Angola    6776381.0    6927269.0    7094834.0    7277960.0
# 3                Albania    2135479.0    2187853.0    2243126.0    2296752.0
# 4                Andorra      24276.0      25559.0      26892.0      28232.0
# 5             Arab World  122398374.0  125807419.0  129269375.0  132863416.0
# 6   United Arab Emirates     235499.0     278808.0     332760.0     397174.0
# 7              Argentina   23973058.0   24366439.0   24782949.0   25213388.0
# 8                Armenia    2525065.0    2587706.0    2650484.0    2712781.0
# 9         American Samoa      27292.0      27916.0      28492.0      29014.0
# 10   Antigua and Barbuda      67098.0      68188.0      69176.0      70066.0
#
# ...

# %%
#De aquí en adelante, calculate percentage change: pct_change()

demo_series = demo.apply(lambda x: x.tolist(), axis=1)
demo_series
# Out:
# 0      [Aruba, 59063.0, 59440.0, 59840.0, 60243.0, 60...
# 1      [Afghanistan, 11126123.0, 11417825.0, 11721940...
# 2      [Angola, 6776381.0, 6927269.0, 7094834.0, 7277...
# 3      [Albania, 2135479.0, 2187853.0, 2243126.0, 229...
# 4      [Andorra, 24276.0, 25559.0, 26892.0, 28232.0, ...
# 5      [Arab World, 122398374.0, 125807419.0, 1292693...
# 6      [United Arab Emirates, 235499.0, 278808.0, 332...
# 7      [Argentina, 23973058.0, 24366439.0, 24782949.0...
# 8      [Armenia, 2525065.0, 2587706.0, 2650484.0, 271...
# 9      [American Samoa, 27292.0, 27916.0, 28492.0, 29...
# 10     [Antigua and Barbuda, 67098.0, 68188.0, 69176....
# 11     [Australia, 12507000.0, 12937000.0, 13177000.0...
# 12     [Austria, 7467086.0, 7500482.0, 7544201.0, 758...
# 13     [Azerbaijan, 5180025.0, 5284532.0, 5385267.0, ...
# 14     [Burundi, 3455606.0, 3505391.0, 3544047.0, 357...
# 15     [Belgium, 9655549.0, 9673162.0, 9711115.0, 974...
# ...

# %%
#Tenemos que transponer el Dataframe para poder recorrer cada serie.
#.iloc para poner los años como index.
demoT = demo.T
demoT.columns = demoT.iloc[0]
demoT
# Out:
# Country Name   Aruba  Afghanistan       Angola      Albania  Andorra  \
# Country Name   Aruba  Afghanistan       Angola      Albania  Andorra
# 1970           59063  1.11261e+07  6.77638e+06  2.13548e+06    24276
# 1971           59440  1.14178e+07  6.92727e+06  2.18785e+06    25559
# 1972           59840  1.17219e+07  7.09483e+06  2.24313e+06    26892
# 1973           60243  1.20278e+07  7.27796e+06  2.29675e+06    28232
# 1974           60528  1.23215e+07  7.47434e+06  2.35012e+06    29520
# 1975           60657  1.25903e+07  7.68248e+06  2.40483e+06    30705
# 1976           60586  1.28403e+07    7.901e+06  2.45853e+06    31777
# 1977           60366  1.30675e+07  8.13099e+06  2.51355e+06    32771
# 1978           60103  1.32377e+07  8.37615e+06  2.56627e+06    33737
# 1979           59980  1.33067e+07  8.64152e+06  2.61783e+06    34818
# 1980           60096  1.32484e+07   8.9299e+06    2.672e+06    36067
# 1981           60567   1.3054e+07  9.24451e+06  2.72606e+06    37500
# ...

# %%
#Eliminamos la fila que hemos puesto como título

demoT = demoT.drop('Country Name', axis=0)
demoT
# Out:
# Country Name   Aruba  Afghanistan       Angola      Albania Andorra  \
# 1970           59063  1.11261e+07  6.77638e+06  2.13548e+06   24276
# 1971           59440  1.14178e+07  6.92727e+06  2.18785e+06   25559
# 1972           59840  1.17219e+07  7.09483e+06  2.24313e+06   26892
# 1973           60243  1.20278e+07  7.27796e+06  2.29675e+06   28232
# 1974           60528  1.23215e+07  7.47434e+06  2.35012e+06   29520
# 1975           60657  1.25903e+07  7.68248e+06  2.40483e+06   30705
# 1976           60586  1.28403e+07    7.901e+06  2.45853e+06   31777
# 1977           60366  1.30675e+07  8.13099e+06  2.51355e+06   32771
# 1978           60103  1.32377e+07  8.37615e+06  2.56627e+06   33737
# 1979           59980  1.33067e+07  8.64152e+06  2.61783e+06   34818
# 1980           60096  1.32484e+07   8.9299e+06    2.672e+06   36067
# 1981           60567   1.3054e+07  9.24451e+06  2.72606e+06   37500
# 1982           61345  1.27496e+07  9.58216e+06  2.78428e+06   39114
# ...

# %%
#Vamos a crear una tabla con los 5 países más poblados. 
#Queremos comparar su crecimiento de población.
demoT_maspob = demoT[['China', 'India', 'United States', 'Indonesia', 'Pakistan']].copy()
demoT_maspob
# Out:
# Country Name        China        India United States    Indonesia     Pakistan
# 1970          8.18315e+08  5.53579e+08   2.05052e+08  1.14835e+08  5.80908e+07
# 1971          8.41105e+08  5.66225e+08   2.07661e+08  1.17922e+08  5.96871e+07
# 1972           8.6203e+08  5.79412e+08   2.09896e+08   1.2106e+08  6.13383e+07
# 1973           8.8194e+08  5.93059e+08   2.11909e+08  1.24242e+08  6.30595e+07
# 1974           9.0035e+08   6.0705e+08   2.13854e+08  1.27465e+08  6.48708e+07
# 1975          9.16395e+08  6.21302e+08   2.15973e+08  1.30724e+08  6.67879e+07
# 1976          9.30685e+08  6.35772e+08   2.18035e+08  1.34011e+08  6.88132e+07
# 1977          9.43455e+08  6.50485e+08   2.20239e+08  1.37322e+08  7.09462e+07
# 1978          9.56165e+08  6.65502e+08   2.22585e+08  1.40666e+08  7.31949e+07
# 1979          9.69005e+08  6.80916e+08   2.25055e+08  1.44054e+08  7.55677e+07
# 1980          9.81235e+08  6.96784e+08   2.27225e+08   1.4749e+08  7.80681e+07
# ...

# %%
#Convertir los index en ints para que lo coja el matplotlib. Intento fallido de usar matplotlib.
demoT_maspob_index = demoT_maspob.index.astype(int)

# %%
print(type(demoT_maspob_index[0]))

#Vemos que ahora los índices son ints, debería cogerlo el matplotlib
# Out:
# <class 'numpy.int64'>

# %%
lines = demoT_maspob.plot.line(title = "Most populated countries \n Population \n x axis = 70's, 80's, 90's, 00's, 10's", legend=True, use_index=True, figsize=(16,9))
lines

#Podemos ver cómo China en los 80's alcanza el billón de habitantes y sigue creciendo hasta los 00's que frena un poco por el single child policy.
#Igualmente India llega al billón más adelante, en los 00's, y sigue creciendo hasta alcanzar prácticamente a China hoy en día.

# %%
#Podemos aplicar el pct_change() porque cada columna es una series.

print(type(demoT))
print(type(demoT.Aruba))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
#La tabla de pct_change() de todos los países.

demoT_pctchange = demoT.pct_change()*100
demoT_pctchange = demoT_pctchange.round(2)
demoT_pctchange
# Out:
# Country Name  Aruba  Afghanistan  Angola  Albania  Andorra  Arab World  \
# 1970            NaN          NaN     NaN      NaN      NaN         NaN
# 1971           0.64         2.62    2.23     2.45     5.29        2.79
# 1972           0.67         2.66    2.42     2.53     5.22        2.75
# 1973           0.67         2.61    2.58     2.39     4.98        2.78
# 1974           0.47         2.44    2.70     2.32     4.56        2.89
# 1975           0.21         2.18    2.78     2.33     4.01        3.03
# 1976          -0.12         1.99    2.84     2.23     3.49        3.19
# 1977          -0.36         1.77    2.91     2.24     3.13        3.30
# 1978          -0.44         1.30    3.02     2.10     2.95        3.36
# 1979          -0.20         0.52    3.17     2.01     3.20        3.36
# 1980           0.19        -0.44    3.34     2.07     3.59        3.30
# 1981           0.78        -1.47    3.52     2.02     3.97        3.24
# ...

# %%
#Vamos a quedarnos con los 3 países más poblados y los 3 países menos poblados. 
#Queremos comparar su crecimiento de población con el de España y el total de crecimiento de población mundial.

demoT_pctchange_pob = demoT_pctchange[['China', 'India', 'United States', 'Spain', 'Tuvalu', 'Nauru', 'San Marino', 'World']].copy()
demoT_pctchange_pob
# Out:
# Country Name  China  India  United States  Spain  Tuvalu  Nauru  San Marino  \
# 1970            NaN    NaN            NaN    NaN     NaN    NaN         NaN
# 1971           2.78   2.28           1.27   1.21    1.07   1.94        0.86
# 1972           2.49   2.33           1.08   1.11    1.04   1.87        0.49
# 1973           2.31   2.36           0.96   1.11    1.06   1.76        0.35
# 1974           2.09   2.36           0.92   1.10    1.05   1.60        0.49
# 1975           1.78   2.35           0.99   1.09    0.80   1.41        0.88
# 1976           1.56   2.33           0.95   1.06    0.94   1.22        1.24
# 1977           1.37   2.31           1.01   1.03    0.86   1.10        1.58
# 1978           1.35   2.31           1.07   0.97    0.92   1.05        1.79
# 1979           1.34   2.32           1.11   0.89    0.94   1.12        1.79
# 1980           1.26   2.33           0.96   0.81    1.13   1.28        1.57
# ...

# %%
lines = demoT_pctchange_pob.plot.line(title = "Percentage Change \n Most to least populated contries vs World population \n x axis = 70's, 80's, 90's, 00's, 10's \n y axis = %", legend=True, use_index=True, figsize=(17,10))
lines

#Vemos en esta tabla de Percentage Change cómo curiosamente Nauru, que es un estado de Micronesia, situado en el
#océano Pacífico, que comprende una sola isla justo al sur de la línea del ecuador; cambia drásticamente de población.
#En el 2014, Nauru aumentó su poplación en casi un 10% . Según datos publicados por la ONU, esto se debió a entrada
#de inmigrantes (refugiados). 
#También es interesante fijarse en la línea roja, España, vemos como en los años 80's la población disminuye. En los
#00's sube mucho, hasta un 2%.
